# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Final Project"

# %%
engine = create_engine(db_string)

# %%
connection = engine.connect()

# %%
data = pd.read_sql_query("SELECT * FROM combined_wine_quality",connection)

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# id                        int64
# dtype: object

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               4.6              0.52         0.15             2.1      0.054
# 1               4.7              0.60         0.17             2.3      0.058
# 2               4.9              0.42         0.00             2.1      0.048
# 3               5.0              0.38         0.01             1.6      0.048
# 4               5.0              0.40         0.50             4.3      0.046
# ...             ...               ...          ...             ...        ...
# 6492           14.2              0.27         0.49             1.1      0.037
# 6493            7.9              0.20         0.39             1.0      0.041
# 6494            8.0              0.13         0.25             1.1      0.033
# 6495            9.7              0.24         0.49             4.9      0.032
# 6496           10.0              0.91         0.42             1.6      0.056
#
# ...
